# %%
from fooof.objs import FOOOF, FOOOFGroup
from fooof.plts.aperiodic import plot_aperiodic_params
from fooof.utils.download import load_fooof_data
import numpy as np
# Out:
# /var/folders/sx/8ph2ml7d6wd_mnj9plf162c80000gq/T/ipykernel_27690/3743853793.py:1: DeprecationWarning:
# The `fooof` package is being deprecated and replaced by the `specparam` (spectral parameterization) package.
# This version of `fooof` (1.1) is fully functional, but will not be further updated.
# New projects are recommended to update to using `specparam` (see Changelog for details).
#   from fooof.objs import FOOOF, FOOOFGroup

# %%
freq_range = [1, 40]
freqs = np.load('/Users/purdonlabadmin/Documents/fooof/data/freqs.npy')
spectrum = np.load('/Users/purdonlabadmin/Documents/fooof/data/spectrum.npy')

# %%
# Initialize FOOOF object
fm = FOOOF( aperiodic_mode = 'knee')

# Model the power spectrum with FOOOF, and print out a report
fm.report(freqs, spectrum, freq_range, plt_log=True)
# Out:
# aperiodic bounds ((-inf, -inf, -inf), (inf, inf, inf))
#
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.49
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# ...
#
#                                    FOOOF - POWER SPECTRUM MODEL
#
#                         The model was run on the frequency range 1 - 40 Hz
#                                  Frequency Resolution is 0.49 Hz
#
#                          Aperiodic Parameters (offset, knee, exponent):
#                                      -21.1604, 2.6773, 0.9945
#
#                                        2 peaks were found:
#                                 CF:   9.45, PW:  0.937, BW:  1.59
#                                 CF:  18.32, PW:  0.286, BW:  1.81
#
# ...

# %%
fm_lorentzian = FOOOF( aperiodic_mode = 'lorentzian')
fm_lorentzian.report(freqs, spectrum, freq_range, plt_log=True)
# Out:
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.49
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# guess [-21.53869024   1.           0.91155817]
# ap bounds ((None, None), (-1, 3), (None, None))
# guess [-21.87675593   1.11711215   1.97927403]
# ap bounds ((None, None), (-1, 3), (None, None))
# loop to find peaks
# loop to find peaks
# loop to find peaks
# loop to find peaks
# loop to find peaks
# loop to find peaks
# _fit_peak_guess [[ 9.27734375  2.71632975  3.31766328]
#  [18.5546875   2.28315216  3.73237119]
#  [25.87890625  1.31328201  2.90295537]]
# lo bounds [[1.4648437499995108, 0, 0.25], [7.3575739219816665, 0, 0.25], [17.1700401337597, 0, 0.25]]
# ...
